# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras import models
from keras import layers
import numpy as np
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau

# Define the data generators with data augmentation
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=False,
    dtype='float32',
    validation_split=0.2
)

test_datagen = ImageDataGenerator(rescale=1./255, dtype='float32')

train_set = train_datagen.flow_from_directory(
    'C:\Users\SHAKIB\Documents\AI Projects\SubProject02\Train',
    target_size=(28, 28),
    batch_size=8,
    class_mode='categorical',
    subset='training'
)

validation_set = train_datagen.flow_from_directory(
    'C:\Users\SHAKIB\Documents\AI Projects\SubProject02\Train',
    target_size=(28, 28),
    batch_size=8,
    class_mode='categorical',
    subset='validation'
)

test_set = test_datagen.flow_from_directory(
    'C:\Users\SHAKIB\Documents\AI Projects\SubProject02\Test',
    target_size=(28, 28),
    batch_size=8,
    class_mode='categorical'
)

# Define ensemble parameters
num_models = 3
ensemble_models = []
ensemble_test_accuracies = []

# Train multiple models
for i in range(num_models):
    # Build the convnet model
    network = models.Sequential()
    network.add(layers.Conv2D(128, (3, 3), activation='relu', padding='same', input_shape=(28, 28, 3)))
    network.add(layers.MaxPooling2D((2, 2)))
    network.add(layers.Conv2D(256, (3, 3), activation='relu', padding='same'))
    network.add(layers.MaxPooling2D((2, 2)))
    network.add(layers.Conv2D(256, (3, 3), activation='relu', padding='same'))
    network.add(layers.MaxPooling2D((2, 2)))
    network.add(layers.Conv2D(256, (3, 3), activation='relu', padding='same'))
    network.add(layers.MaxPooling2D((2, 2)))
    network.add(layers.Flatten())
    network.add(layers.Dense(128, activation='relu'))
    network.add(layers.Dense(256, activation='relu'))
    network.add(layers.Dense(10, activation='softmax'))

    optimizer = Adam(learning_rate=0.001)
    network.compile(optimizer=optimizer,
                    loss='categorical_crossentropy',
                    metrics=['accuracy'])

    # Define the learning rate scheduler
    lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=3, verbose=1)

    # Train the model with the learning rate scheduler
    history = network.fit(train_set,
                          validation_data=validation_set,
                          epochs=30,
                          callbacks=[lr_scheduler],
                          verbose=1)

    # Evaluate the model on the validation set
    val_loss, val_acc = network.evaluate(validation_set)
    print(f"Model {i+1} validation accuracy: {val_acc}")

    # Evaluate the model on the test set
    test_loss, test_acc = network.evaluate(test_set)
    ensemble_test_accuracies.append(test_acc)
    print(f"Model {i+1} test accuracy: {test_acc}")

    # Add the trained model to the ensemble
    ensemble_models.append(network)


    # Plot the result figures
    # Loss figure
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title(f"Train Loss - Model {i+1}")
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc='upper right')
    plt.show()

    # Accuracy figure
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title(f"Model Accuracy - Model {i+1}")
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc='upper right')
    plt.show()

# Get the index of the best model based on test accuracy
best_model_index = np.argmax(ensemble_test_accuracies)
best_model = ensemble_models[best_model_index]

# Evaluate the best model on the test set
best_model_loss, best_model_acc = best_model.evaluate(test_set)
print('Best Model Test Accuracy:', best_model_acc)
# Out:
# Found 1418 images belonging to 10 classes.
# Found 350 images belonging to 10 classes.
# Found 1000 images belonging to 10 classes.
# Epoch 1/30
# 178/178 [==============================] - 5s 26ms/step - loss: 1.9624 - accuracy: 0.2870 - val_loss: 1.4532 - val_accuracy: 0.5114 - lr: 0.0010
# Epoch 2/30
# 178/178 [==============================] - 5s 25ms/step - loss: 0.9181 - accuracy: 0.6862 - val_loss: 0.6780 - val_accuracy: 0.7971 - lr: 0.0010
# Epoch 3/30
# 178/178 [==============================] - 5s 25ms/step - loss: 0.5237 - accuracy: 0.8378 - val_loss: 0.4816 - val_accuracy: 0.8257 - lr: 0.0010
# Epoch 4/30
# 178/178 [==============================] - 4s 25ms/step - loss: 0.3485 - accuracy: 0.8935 - val_loss: 0.7336 - val_accuracy: 0.7714 - lr: 0.0010
# Epoch 5/30
# 178/178 [==============================] - 5s 26ms/step - loss: 0.2627 - accuracy: 0.9126 - val_loss: 0.3398 - val_accuracy: 0.8943 - lr: 0.0010
# Epoch 6/30
# 178/178 [==============================] - 5s 28ms/step - loss: 0.2459 - accuracy: 0.9316 - val_loss: 0.2891 - val_accuracy: 0.9057 - lr: 0.0010
# Epoch 7/30
# 178/178 [==============================] - 5s 28ms/step - loss: 0.2150 - accuracy: 0.9372 - val_loss: 0.2347 - val_accuracy: 0.9429 - lr: 0.0010
# Epoch 8/30
# 178/178 [==============================] - 5s 28ms/step - loss: 0.1868 - accuracy: 0.9478 - val_loss: 0.3052 - val_accuracy: 0.9114 - lr: 0.0010
# Epoch 9/30
# 178/178 [==============================] - 5s 30ms/step - loss: 0.1939 - accuracy: 0.9394 - val_loss: 0.2483 - val_accuracy: 0.9200 - lr: 0.0010
# Epoch 10/30
# 178/178 [==============================] - ETA: 0s - loss: 0.1281 - accuracy: 0.9542
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 178/178 [==============================] - 5s 30ms/step - loss: 0.1281 - accuracy: 0.9542 - val_loss: 0.2372 - val_accuracy: 0.9457 - lr: 0.0010
# Epoch 11/30
# 178/178 [==============================] - 5s 29ms/step - loss: 0.0986 - accuracy: 0.9725 - val_loss: 0.1692 - val_accuracy: 0.9629 - lr: 1.0000e-04
# Epoch 12/30
# 178/178 [==============================] - 5s 29ms/step - loss: 0.0624 - accuracy: 0.9810 - val_loss: 0.1388 - val_accuracy: 0.9686 - lr: 1.0000e-04
# Epoch 13/30
# 178/178 [==============================] - 5s 29ms/step - loss: 0.0650 - accuracy: 0.9824 - val_loss: 0.1156 - val_accuracy: 0.9771 - lr: 1.0000e-04
# Epoch 14/30
# 178/178 [==============================] - 5s 28ms/step - loss: 0.0614 - accuracy: 0.9810 - val_loss: 0.1331 - val_accuracy: 0.9629 - lr: 1.0000e-04
# Epoch 15/30
# 178/178 [==============================] - 5s 29ms/step - loss: 0.0743 - accuracy: 0.9795 - val_loss: 0.1455 - val_accuracy: 0.9743 - lr: 1.0000e-04
# Epoch 16/30
# 178/178 [==============================] - 5s 29ms/step - loss: 0.0724 - accuracy: 0.9760 - val_loss: 0.1107 - val_accuracy: 0.9771 - lr: 1.0000e-04
# Epoch 17/30
# 178/178 [==============================] - 5s 29ms/step - loss: 0.0586 - accuracy: 0.9831 - val_loss: 0.0975 - val_accuracy: 0.9743 - lr: 1.0000e-04
# Epoch 18/30
# 178/178 [==============================] - 5s 29ms/step - loss: 0.0536 - accuracy: 0.9831 - val_loss: 0.0971 - val_accuracy: 0.9714 - lr: 1.0000e-04
# Epoch 19/30
# 178/178 [==============================] - 5s 29ms/step - loss: 0.0562 - accuracy: 0.9824 - val_loss: 0.1202 - val_accuracy: 0.9629 - lr: 1.0000e-04
# Epoch 20/30
# 178/178 [==============================] - 5s 29ms/step - loss: 0.0292 - accuracy: 0.9915 - val_loss: 0.0938 - val_accuracy: 0.9771 - lr: 1.0000e-04
# Epoch 21/30
# 178/178 [==============================] - 5s 29ms/step - loss: 0.0445 - accuracy: 0.9845 - val_loss: 0.1344 - val_accuracy: 0.9714 - lr: 1.0000e-04
# Epoch 22/30
# 178/178 [==============================] - 5s 29ms/step - loss: 0.0501 - accuracy: 0.9859 - val_loss: 0.1349 - val_accuracy: 0.9657 - lr: 1.0000e-04
# Epoch 23/30
# 177/178 [============================>.] - ETA: 0s - loss: 0.0417 - accuracy: 0.9872
# Epoch 23: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 178/178 [==============================] - 5s 29ms/step - loss: 0.0415 - accuracy: 0.9873 - val_loss: 0.1329 - val_accuracy: 0.9743 - lr: 1.0000e-04
# Epoch 24/30
# 178/178 [==============================] - 5s 29ms/step - loss: 0.0306 - accuracy: 0.9908 - val_loss: 0.1095 - val_accuracy: 0.9743 - lr: 1.0000e-05
# Epoch 25/30
# 178/178 [==============================] - 5s 29ms/step - loss: 0.0402 - accuracy: 0.9859 - val_loss: 0.1215 - val_accuracy: 0.9714 - lr: 1.0000e-05
# Epoch 26/30
# 177/178 [============================>.] - ETA: 0s - loss: 0.0312 - accuracy: 0.9894
# Epoch 26: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 178/178 [==============================] - 5s 28ms/step - loss: 0.0311 - accuracy: 0.9894 - val_loss: 0.1279 - val_accuracy: 0.9657 - lr: 1.0000e-05
# Epoch 27/30
# 178/178 [==============================] - 5s 28ms/step - loss: 0.0344 - accuracy: 0.9887 - val_loss: 0.1126 - val_accuracy: 0.9771 - lr: 1.0000e-06
# Epoch 28/30
# 178/178 [==============================] - 5s 27ms/step - loss: 0.0423 - accuracy: 0.9894 - val_loss: 0.1251 - val_accuracy: 0.9714 - lr: 1.0000e-06
# Epoch 29/30
# 178/178 [==============================] - ETA: 0s - loss: 0.0360 - accuracy: 0.9880
# Epoch 29: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# 178/178 [==============================] - 5s 28ms/step - loss: 0.0360 - accuracy: 0.9880 - val_loss: 0.1161 - val_accuracy: 0.9743 - lr: 1.0000e-06
# Epoch 30/30
# 178/178 [==============================] - 5s 28ms/step - loss: 0.0351 - accuracy: 0.9880 - val_loss: 0.1163 - val_accuracy: 0.9771 - lr: 1.0000e-07
# 44/44 [==============================] - 0s 8ms/step - loss: 0.1356 - accuracy: 0.9657
# Model 1 validation accuracy: 0.9657142758369446
# 125/125 [==============================] - 1s 9ms/step - loss: 0.0689 - accuracy: 0.9780
# Model 1 test accuracy: 0.9779999852180481
# Epoch 1/30
# 178/178 [==============================] - 6s 29ms/step - loss: 2.0003 - accuracy: 0.2701 - val_loss: 1.4881 - val_accuracy: 0.4629 - lr: 0.0010
# Epoch 2/30
# 178/178 [==============================] - 5s 29ms/step - loss: 0.8151 - accuracy: 0.7264 - val_loss: 0.6698 - val_accuracy: 0.7543 - lr: 0.0010
# Epoch 3/30
# 178/178 [==============================] - 5s 29ms/step - loss: 0.4725 - accuracy: 0.8526 - val_loss: 0.3292 - val_accuracy: 0.9057 - lr: 0.0010
# Epoch 4/30
# 178/178 [==============================] - 5s 29ms/step - loss: 0.2803 - accuracy: 0.9083 - val_loss: 0.4061 - val_accuracy: 0.8943 - lr: 0.0010
# Epoch 5/30
# 178/178 [==============================] - 5s 29ms/step - loss: 0.2263 - accuracy: 0.9267 - val_loss: 0.2218 - val_accuracy: 0.9429 - lr: 0.0010
# Epoch 6/30
# 178/178 [==============================] - 5s 29ms/step - loss: 0.1707 - accuracy: 0.9549 - val_loss: 0.3196 - val_accuracy: 0.9143 - lr: 0.0010
# Epoch 7/30
# 178/178 [==============================] - 5s 29ms/step - loss: 0.1759 - accuracy: 0.9457 - val_loss: 0.1734 - val_accuracy: 0.9514 - lr: 0.0010
# Epoch 8/30
# 178/178 [==============================] - 5s 29ms/step - loss: 0.1882 - accuracy: 0.9422 - val_loss: 0.1766 - val_accuracy: 0.9543 - lr: 0.0010
# Epoch 9/30
# 178/178 [==============================] - 5s 29ms/step - loss: 0.2025 - accuracy: 0.9429 - val_loss: 0.1888 - val_accuracy: 0.9543 - lr: 0.0010
# Epoch 10/30
# 178/178 [==============================] - ETA: 0s - loss: 0.1543 - accuracy: 0.9542
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 178/178 [==============================] - 5s 29ms/step - loss: 0.1543 - accuracy: 0.9542 - val_loss: 0.2146 - val_accuracy: 0.9314 - lr: 0.0010
# Epoch 11/30
# 178/178 [==============================] - 5s 29ms/step - loss: 0.0876 - accuracy: 0.9753 - val_loss: 0.1191 - val_accuracy: 0.9657 - lr: 1.0000e-04
# Epoch 12/30
# 178/178 [==============================] - 5s 29ms/step - loss: 0.0634 - accuracy: 0.9795 - val_loss: 0.1525 - val_accuracy: 0.9600 - lr: 1.0000e-04
# Epoch 13/30
# 178/178 [==============================] - 5s 28ms/step - loss: 0.0577 - accuracy: 0.9803 - val_loss: 0.1039 - val_accuracy: 0.9743 - lr: 1.0000e-04
# Epoch 14/30
# 178/178 [==============================] - 5s 29ms/step - loss: 0.0508 - accuracy: 0.9817 - val_loss: 0.1504 - val_accuracy: 0.9571 - lr: 1.0000e-04
# Epoch 15/30
# 178/178 [==============================] - 5s 29ms/step - loss: 0.0444 - accuracy: 0.9873 - val_loss: 0.1691 - val_accuracy: 0.9686 - lr: 1.0000e-04
# Epoch 16/30
# 178/178 [==============================] - 5s 29ms/step - loss: 0.0584 - accuracy: 0.9838 - val_loss: 0.0952 - val_accuracy: 0.9800 - lr: 1.0000e-04
# Epoch 17/30
# 178/178 [==============================] - 5s 29ms/step - loss: 0.0540 - accuracy: 0.9859 - val_loss: 0.1696 - val_accuracy: 0.9571 - lr: 1.0000e-04
# Epoch 18/30
# 178/178 [==============================] - 5s 29ms/step - loss: 0.0542 - accuracy: 0.9831 - val_loss: 0.1634 - val_accuracy: 0.9629 - lr: 1.0000e-04
# Epoch 19/30
# 177/178 [============================>.] - ETA: 0s - loss: 0.0299 - accuracy: 0.9908
# Epoch 19: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 178/178 [==============================] - 5s 29ms/step - loss: 0.0298 - accuracy: 0.9908 - val_loss: 0.1187 - val_accuracy: 0.9743 - lr: 1.0000e-04
# Epoch 20/30
# 178/178 [==============================] - 5s 29ms/step - loss: 0.0408 - accuracy: 0.9880 - val_loss: 0.1180 - val_accuracy: 0.9657 - lr: 1.0000e-05
# Epoch 21/30
# 178/178 [==============================] - 5s 30ms/step - loss: 0.0307 - accuracy: 0.9887 - val_loss: 0.1318 - val_accuracy: 0.9686 - lr: 1.0000e-05
# Epoch 22/30
# 178/178 [==============================] - ETA: 0s - loss: 0.0364 - accuracy: 0.9852
# Epoch 22: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 178/178 [==============================] - 5s 30ms/step - loss: 0.0364 - accuracy: 0.9852 - val_loss: 0.1341 - val_accuracy: 0.9714 - lr: 1.0000e-05
# Epoch 23/30
# 178/178 [==============================] - 6s 32ms/step - loss: 0.0413 - accuracy: 0.9859 - val_loss: 0.1570 - val_accuracy: 0.9657 - lr: 1.0000e-06
# Epoch 24/30
# 178/178 [==============================] - 6s 32ms/step - loss: 0.0270 - accuracy: 0.9922 - val_loss: 0.1459 - val_accuracy: 0.9600 - lr: 1.0000e-06
# Epoch 25/30
# 177/178 [============================>.] - ETA: 0s - loss: 0.0438 - accuracy: 0.9865
# Epoch 25: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# 178/178 [==============================] - 6s 32ms/step - loss: 0.0436 - accuracy: 0.9866 - val_loss: 0.1275 - val_accuracy: 0.9657 - lr: 1.0000e-06
# Epoch 26/30
# 178/178 [==============================] - 6s 32ms/step - loss: 0.0342 - accuracy: 0.9859 - val_loss: 0.1458 - val_accuracy: 0.9600 - lr: 1.0000e-07
# Epoch 27/30
# 178/178 [==============================] - 5s 31ms/step - loss: 0.0304 - accuracy: 0.9915 - val_loss: 0.1314 - val_accuracy: 0.9657 - lr: 1.0000e-07
# Epoch 28/30
# 178/178 [==============================] - ETA: 0s - loss: 0.0349 - accuracy: 0.9880
# Epoch 28: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-08.
# 178/178 [==============================] - 6s 31ms/step - loss: 0.0349 - accuracy: 0.9880 - val_loss: 0.0963 - val_accuracy: 0.9657 - lr: 1.0000e-07
# Epoch 29/30
# 178/178 [==============================] - 5s 30ms/step - loss: 0.0328 - accuracy: 0.9880 - val_loss: 0.1706 - val_accuracy: 0.9600 - lr: 1.0000e-08
# Epoch 30/30
# 178/178 [==============================] - 5s 29ms/step - loss: 0.0296 - accuracy: 0.9915 - val_loss: 0.1457 - val_accuracy: 0.9800 - lr: 1.0000e-08
# 44/44 [==============================] - 0s 8ms/step - loss: 0.1195 - accuracy: 0.9686
# Model 2 validation accuracy: 0.9685714244842529
# 125/125 [==============================] - 1s 9ms/step - loss: 0.0529 - accuracy: 0.9850
# Model 2 test accuracy: 0.9850000143051147
# Epoch 1/30
# 178/178 [==============================] - 6s 30ms/step - loss: 2.0964 - accuracy: 0.2348 - val_loss: 1.4696 - val_accuracy: 0.5143 - lr: 0.0010
# Epoch 2/30
# 178/178 [==============================] - 5s 29ms/step - loss: 0.9786 - accuracy: 0.6481 - val_loss: 0.6459 - val_accuracy: 0.7971 - lr: 0.0010
# Epoch 3/30
# 178/178 [==============================] - 5s 29ms/step - loss: 0.5282 - accuracy: 0.8343 - val_loss: 0.4193 - val_accuracy: 0.8657 - lr: 0.0010
# Epoch 4/30
# 178/178 [==============================] - 5s 29ms/step - loss: 0.3369 - accuracy: 0.8956 - val_loss: 0.2278 - val_accuracy: 0.9314 - lr: 0.0010
# Epoch 5/30
# 178/178 [==============================] - 5s 30ms/step - loss: 0.2286 - accuracy: 0.9224 - val_loss: 0.2157 - val_accuracy: 0.9514 - lr: 0.0010
# Epoch 6/30
# 178/178 [==============================] - 5s 29ms/step - loss: 0.2126 - accuracy: 0.9365 - val_loss: 0.2780 - val_accuracy: 0.9200 - lr: 0.0010
# Epoch 7/30
# 178/178 [==============================] - 5s 29ms/step - loss: 0.2252 - accuracy: 0.9309 - val_loss: 0.2503 - val_accuracy: 0.9086 - lr: 0.0010
# Epoch 8/30
# 178/178 [==============================] - ETA: 0s - loss: 0.2040 - accuracy: 0.9344
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 178/178 [==============================] - 5s 30ms/step - loss: 0.2040 - accuracy: 0.9344 - val_loss: 0.2365 - val_accuracy: 0.9429 - lr: 0.0010
# Epoch 9/30
# 178/178 [==============================] - 5s 30ms/step - loss: 0.1026 - accuracy: 0.9683 - val_loss: 0.1337 - val_accuracy: 0.9657 - lr: 1.0000e-04
# Epoch 10/30
# 178/178 [==============================] - 5s 30ms/step - loss: 0.0841 - accuracy: 0.9746 - val_loss: 0.1157 - val_accuracy: 0.9714 - lr: 1.0000e-04
# Epoch 11/30
# 178/178 [==============================] - 5s 30ms/step - loss: 0.0858 - accuracy: 0.9725 - val_loss: 0.1604 - val_accuracy: 0.9686 - lr: 1.0000e-04
# Epoch 12/30
# 178/178 [==============================] - 5s 29ms/step - loss: 0.0667 - accuracy: 0.9781 - val_loss: 0.1081 - val_accuracy: 0.9629 - lr: 1.0000e-04
# Epoch 13/30
# 178/178 [==============================] - 5s 30ms/step - loss: 0.0753 - accuracy: 0.9746 - val_loss: 0.1550 - val_accuracy: 0.9600 - lr: 1.0000e-04
# Epoch 14/30
# 178/178 [==============================] - 5s 30ms/step - loss: 0.0711 - accuracy: 0.9803 - val_loss: 0.1264 - val_accuracy: 0.9600 - lr: 1.0000e-04
# Epoch 15/30
# 178/178 [==============================] - ETA: 0s - loss: 0.0509 - accuracy: 0.9873
# Epoch 15: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 178/178 [==============================] - 5s 30ms/step - loss: 0.0509 - accuracy: 0.9873 - val_loss: 0.1129 - val_accuracy: 0.9657 - lr: 1.0000e-04
# Epoch 16/30
# 178/178 [==============================] - 5s 30ms/step - loss: 0.0636 - accuracy: 0.9781 - val_loss: 0.1567 - val_accuracy: 0.9514 - lr: 1.0000e-05
# Epoch 17/30
# 178/178 [==============================] - 5s 30ms/step - loss: 0.0479 - accuracy: 0.9852 - val_loss: 0.1007 - val_accuracy: 0.9771 - lr: 1.0000e-05
# Epoch 18/30
# 178/178 [==============================] - 5s 30ms/step - loss: 0.0482 - accuracy: 0.9845 - val_loss: 0.1198 - val_accuracy: 0.9743 - lr: 1.0000e-05
# Epoch 19/30
# 178/178 [==============================] - 5s 31ms/step - loss: 0.0671 - accuracy: 0.9788 - val_loss: 0.0923 - val_accuracy: 0.9657 - lr: 1.0000e-05
# Epoch 20/30
# 178/178 [==============================] - 5s 31ms/step - loss: 0.0645 - accuracy: 0.9824 - val_loss: 0.1422 - val_accuracy: 0.9543 - lr: 1.0000e-05
# Epoch 21/30
# 178/178 [==============================] - 6s 31ms/step - loss: 0.0624 - accuracy: 0.9817 - val_loss: 0.1286 - val_accuracy: 0.9600 - lr: 1.0000e-05
# Epoch 22/30
# 178/178 [==============================] - ETA: 0s - loss: 0.0592 - accuracy: 0.9795
# Epoch 22: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 178/178 [==============================] - 5s 29ms/step - loss: 0.0592 - accuracy: 0.9795 - val_loss: 0.1274 - val_accuracy: 0.9629 - lr: 1.0000e-05
# Epoch 23/30
# 178/178 [==============================] - 5s 30ms/step - loss: 0.0395 - accuracy: 0.9908 - val_loss: 0.1114 - val_accuracy: 0.9600 - lr: 1.0000e-06
# Epoch 24/30
# 178/178 [==============================] - 5s 29ms/step - loss: 0.0484 - accuracy: 0.9824 - val_loss: 0.1057 - val_accuracy: 0.9686 - lr: 1.0000e-06
# Epoch 25/30
# 177/178 [============================>.] - ETA: 0s - loss: 0.0496 - accuracy: 0.9830
# Epoch 25: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# 178/178 [==============================] - 5s 29ms/step - loss: 0.0493 - accuracy: 0.9831 - val_loss: 0.1057 - val_accuracy: 0.9657 - lr: 1.0000e-06
# Epoch 26/30
# 178/178 [==============================] - 5s 29ms/step - loss: 0.0469 - accuracy: 0.9838 - val_loss: 0.1331 - val_accuracy: 0.9686 - lr: 1.0000e-07
# Epoch 27/30
# 178/178 [==============================] - 5s 30ms/step - loss: 0.0580 - accuracy: 0.9831 - val_loss: 0.0961 - val_accuracy: 0.9686 - lr: 1.0000e-07
# Epoch 28/30
# 178/178 [==============================] - ETA: 0s - loss: 0.0460 - accuracy: 0.9845
# Epoch 28: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-08.
# 178/178 [==============================] - 5s 30ms/step - loss: 0.0460 - accuracy: 0.9845 - val_loss: 0.1143 - val_accuracy: 0.9714 - lr: 1.0000e-07
# Epoch 29/30
# 178/178 [==============================] - 5s 29ms/step - loss: 0.0469 - accuracy: 0.9880 - val_loss: 0.1505 - val_accuracy: 0.9571 - lr: 1.0000e-08
# Epoch 30/30
# 178/178 [==============================] - 5s 29ms/step - loss: 0.0583 - accuracy: 0.9795 - val_loss: 0.0981 - val_accuracy: 0.9800 - lr: 1.0000e-08
# 44/44 [==============================] - 0s 8ms/step - loss: 0.1362 - accuracy: 0.9600
# Model 3 validation accuracy: 0.9599999785423279
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0822 - accuracy: 0.9750
# Model 3 test accuracy: 0.9750000238418579
# 125/125 [==============================] - 1s 8ms/step - loss: 0.0529 - accuracy: 0.9850
# Best Model Test Accuracy: 0.9850000143051147

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import load_img, ImageDataGenerator

# Load the model and test set
model = network  # Your trained model
test_dir = 'D:/DEEP LEARNING/CLEANED DATA SETS AND OUR MODEL/Test'  # Directory path containing test images

test_datagen = ImageDataGenerator(rescale=1./255)  # Rescale the pixel values

test_set = test_datagen.flow_from_directory(
    test_dir,
    target_size=(28, 28),
    batch_size=1,
    class_mode='categorical',
    shuffle=False
)

# Make predictions on the test set
predictions = model.predict(test_set)
predicted_labels = np.argmax(predictions, axis=1)
true_labels = test_set.classes

# Find the indices of incorrectly classified samples
incorrect_indices = np.where(predicted_labels != true_labels)[0]

# Display the incorrectly classified samples
num_images = 50  # Number of images to display
num_rows = int(np.ceil(num_images / 5))  # Number of rows in the subplot grid

fig, axes = plt.subplots(num_rows, 5, figsize=(12, 2.5 * num_rows))
fig.suptitle('Incorrectly Classified 2D Handwritten Digits', fontsize=16)

for i, index in enumerate(incorrect_indices[:num_images]):
    image_path = test_set.filepaths[index]
    image = load_img(image_path)
    row_idx = i // 5
    col_idx = i % 5
    axes[row_idx, col_idx].imshow(image)
    axes[row_idx, col_idx].set_title(f'True: {true_labels[index]}, Predicted: {predicted_labels[index]}')
    axes[row_idx, col_idx].axis('off')

# Adjust the spacing between subplots
fig.tight_layout()

# Show the plot
plt.show()
# Out:
# Found 1000 images belonging to 10 classes.
# 1000/1000 [==============================] - 2s 2ms/step

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import load_img, ImageDataGenerator

# Load the best model and test set
best_model = ensemble_models[best_model_index]  # Your best trained model
test_dir = 'D:/ALI REZA/Deep Learning Final Project/ENDING/final_project_dataset/final_project_dataset/Test'  # Directory path containing test images

test_datagen = ImageDataGenerator(rescale=1./255)  # Rescale the pixel values

test_set = test_datagen.flow_from_directory(
    test_dir,
    target_size=(28, 28),
    batch_size=1,
    class_mode='categorical',
    shuffle=False
)

# Make predictions on the test set using the best model
predictions = best_model.predict(test_set)
predicted_labels = np.argmax(predictions, axis=1)
true_labels = test_set.classes

# Find the indices of incorrectly classified samples
incorrect_indices = np.where(predicted_labels != true_labels)[0]

# Display the incorrectly classified samples
num_images = 50  # Number of images to display
num_rows = int(np.ceil(num_images / 5))  # Number of rows in the subplot grid

fig, axes = plt.subplots(num_rows, 5, figsize=(12, 2.5 * num_rows))
fig.suptitle('Incorrectly Classified 2D Handwritten Digits', fontsize=16)

for i, index in enumerate(incorrect_indices[:num_images]):
    image_path = test_set.filepaths[index]
    image = load_img(image_path)
    row_idx = i // 5
    col_idx = i % 5
    axes[row_idx, col_idx].imshow(image)
    axes[row_idx, col_idx].set_title(f'True: {true_labels[index]}, Predicted: {predicted_labels[index]}')
    axes[row_idx, col_idx].axis('off')

# Adjust the spacing between subplots
fig.tight_layout()

# Show the plot
plt.show()
# Out:
# Found 1000 images belonging to 10 classes.
# 1000/1000 [==============================] - 2s 2ms/step
